# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\meswa\\OneDrive\\Desktop\\new file\\fourth_cle.csv")

# %%
numeric_df = df.select_dtypes(include=['number'])

# %%
numeric_df.corr()['Price']
# Out:
# Unnamed: 0       0.067984
# Unnamed: 0.2     0.067984
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# TouchScreen      0.191226
# IPS              0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns = ['Hybrid','Flash_Storage'],inplace=True)

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df = df[df['Gpu brand']!='ARM']

# %%
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.2 Company   TypeName  Ram  \
# 0           0             0   Apple  Ultrabook    8
# 1           1             1   Apple  Ultrabook    8
#
#                             Gpu  OpSys  Weight       Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0
#
#           PPI       CPU_name  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel

# %%
df = df.drop(columns=['Gpu'])

# %%
def setcategory(text):
    
    if text=='Windows 10' or text=='Windows 7' or text=='Windows 10 S':
        return 'Windows'
    
    elif text=='Mac OS X' or text=='macOS':
        return 'Mac'
    
    else:
        return 'Other'

# %%
df['OpSys'] = df['OpSys'].apply(lambda x:setcategory(x))

# %%
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.2 Company   TypeName  Ram OpSys  Weight       Price  \
# 0           0             0   Apple  Ultrabook    8   Mac    1.37  71378.6832
# 1           1             1   Apple  Ultrabook    8   Mac    1.34  47895.5232
#
#    TouchScreen  IPS         PPI       CPU_name  HDD  SSD Gpu brand
# 0            0    1  226.983005  Intel Core i5    0  128     Intel
# 1            0    0  127.677940  Intel Core i5    0    0     Intel

# %%
df.to_csv("C:\\Users\\meswa\\OneDrive\\Desktop\\new file\\final_cle.csv")
