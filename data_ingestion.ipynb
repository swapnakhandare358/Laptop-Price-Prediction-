# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\meswa\\Downloads\\Python notes amit sir\\32. Laptop_CSV_File.csv 27-01-2026")

# %%
df = df.iloc[:,1:]

# %%
df['Ram'] = df['Ram'].str.replace('GB','')

# %%
df['Ram'] = df['Ram'].astype('int32')

# %%
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df['Weight'] = df['Weight'].astype('float32')

# %%
df.to_csv("C:\\Users\\meswa\\OneDrive\\Desktop\\new file\\first_cle.csv")
